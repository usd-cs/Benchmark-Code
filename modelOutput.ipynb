# %%
import sys

# !{sys.executable} -m pip install seebuoy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from seebuoy import NDBC
import pandas as pd
import numpy as np

ndbc = NDBC()
buoyNum = "44065"
# Information on NDBC's ~1800 buoys and gliders
wave_df = ndbc.stations()

# list all available data for all buoys
df_data = ndbc.available_data()

# Get info on La Jave Bank (42.500N 64.02W) 
# SEEBUOY DATA
see_buoy = ndbc.get_data(str(buoyNum))
see_buoy = see_buoy[::-1]
see_buoy
# Out:
#                      wind_direction  wind_speed  wind_gust  wave_height  \
# date
# 2024-02-13 23:10:00             NaN         8.0       11.0          NaN
# 2024-02-13 23:00:00             NaN         9.0       11.0          NaN
# 2024-02-13 22:50:00             NaN         9.0       11.0          1.2
# 2024-02-13 22:40:00             NaN         8.0       10.0          NaN
# 2024-02-13 22:30:00             NaN         9.0       11.0          NaN
# ...                             ...         ...        ...          ...
# 2023-12-30 00:40:00             NaN         5.0        6.0          0.8
# 2023-12-30 00:30:00             NaN         5.0        7.0          NaN
# 2023-12-30 00:20:00             NaN         4.0        6.0          0.8
# 2023-12-30 00:10:00             NaN         5.0        6.0          0.8
# 2023-12-30 00:00:00             NaN         5.0        6.0          NaN
#
#                      dominant_period  average_period  mean_wave_direction  \
# date
# ...

# %%
see_buoy = see_buoy.dropna(axis=1, how='all')

# %%
see_buoy.columns
# Out:
# Index(['wind_speed', 'wind_gust', 'wave_height', 'dominant_period',
#        'average_period', 'mean_wave_direction', 'pressure', 'water_temp',
#        'pressure_tendency'],
#       dtype='object')

# %%
mean = see_buoy.mean()

# %%
see_buoy
# Out:
#                      wind_speed  wind_gust  wave_height  dominant_period  \
# date
# 2024-02-13 23:10:00         8.0       11.0          NaN              NaN
# 2024-02-13 23:00:00         9.0       11.0          NaN              NaN
# 2024-02-13 22:50:00         9.0       11.0          1.2              4.0
# 2024-02-13 22:40:00         8.0       10.0          NaN              NaN
# 2024-02-13 22:30:00         9.0       11.0          NaN              NaN
# ...                         ...        ...          ...              ...
# 2023-12-30 00:40:00         5.0        6.0          0.8              NaN
# 2023-12-30 00:30:00         5.0        7.0          NaN              NaN
# 2023-12-30 00:20:00         4.0        6.0          0.8              9.0
# 2023-12-30 00:10:00         5.0        6.0          0.8              NaN
# 2023-12-30 00:00:00         5.0        6.0          NaN              NaN
#
#                      average_period  mean_wave_direction  pressure  \
# date
# ...

# %%
waveHeightCols = ['wind_speed', 'wind_gust', 'dominant_period',
       'average_period', 'mean_wave_direction', 'pressure', 'water_temp',
       'pressure_tendency']
dominantPeriodCols = ['wind_speed', 'wind_gust', 'wave_height',
       'average_period', 'mean_wave_direction', 'pressure', 'water_temp',
       'pressure_tendency']

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import train_test_split

# %%
rc = RidgeClassifier(alpha=1)
X_train, X_test, y_train, y_test = train_test_split(see_buoy[waveHeightCols], see_buoy['wave_height'], test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 rc = RidgeClassifier(alpha=1)
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(see_buoy[waveHeightCols], see_buoy['wave_height'], test_size=0.33, random_state=42)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
rc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 rc.fit(X_train, y_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_ridge.py:1433, in RidgeClassifier.fit(self, X, y, sample_weight)
#    1409 @_fit_context(prefer_skip_nested_validation=True)
#    1410 def fit(self, X, y, sample_weight=None):
#    1411     """Fit Ridge classifier model.
#    1412
#    1413     Parameters
#    (...)
# ...
