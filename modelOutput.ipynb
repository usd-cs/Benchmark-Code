# %%
import sys

# !{sys.executable} -m pip install seebuoy
# Out:
# ...
#
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from seebuoy import NDBC
import pandas as pd
import numpy as np

ndbc = NDBC()
buoyNum = "44065"
# Information on NDBC's ~1800 buoys and gliders
wave_df = ndbc.stations()

# list all available data for all buoys
df_data = ndbc.available_data()

# Get info on La Jave Bank (42.500N 64.02W) 
# SEEBUOY DATA
see_buoy = ndbc.get_data(str(buoyNum))
see_buoy = see_buoy[::-1]
see_buoy
# Out:
#                      wind_direction  wind_speed  wind_gust  wave_height  \
# date
# 2024-02-15 22:10:00             NaN         9.0       11.0          NaN
# 2024-02-15 22:00:00             NaN         9.0       11.0          NaN
# 2024-02-15 21:50:00             NaN         8.0       10.0          0.5
# 2024-02-15 21:40:00             NaN         9.0       10.0          NaN
# 2024-02-15 21:30:00             NaN         8.0       10.0          NaN
# ...                             ...         ...        ...          ...
# 2024-01-01 00:40:00             NaN         6.0        8.0          NaN
# 2024-01-01 00:30:00             NaN         7.0        8.0          NaN
# 2024-01-01 00:20:00             NaN         7.0        8.0          0.6
# 2024-01-01 00:10:00             NaN         6.0        8.0          0.6
# 2024-01-01 00:00:00             NaN         6.0        8.0          NaN
#
#                      dominant_period  average_period  mean_wave_direction  \
# date
# ...

# %%
see_buoy = see_buoy.dropna(axis=1, how='all')

# %%
del see_buoy["pressure_tendency"]

# %%
see_buoy = see_buoy.dropna()

# %%
see_buoy = see_buoy * 10

# %%
waveHeightCols = ['wind_speed', 'wind_gust', 'dominant_period',
       'average_period', 'mean_wave_direction', 'pressure', 'water_temp']
dominantPeriodCols = ['wind_speed', 'wind_gust', 'wave_height',
       'average_period', 'mean_wave_direction', 'pressure', 'water_temp']

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import train_test_split

# %%
rc = RidgeClassifier(alpha=1)
X_train, X_test, y_train, y_test = train_test_split(see_buoy[waveHeightCols], see_buoy['wave_height'], test_size=0.2, random_state=42)

# %%
X_train
# Out:
#                      wind_speed  wind_gust  dominant_period  average_period  \
# date
# 2024-01-02 09:20:00        80.0      100.0             30.0            32.0
# 2024-01-05 09:50:00        80.0      120.0             40.0            40.0
# 2024-01-15 08:50:00        70.0      100.0             30.0            37.0
# 2024-01-13 14:50:00       100.0      130.0             90.0            68.0
# 2024-01-10 11:20:00       100.0      160.0            140.0            88.0
# ...                         ...        ...              ...             ...
# 2024-01-20 01:20:00        90.0      110.0             40.0            35.0
# 2024-01-16 13:50:00        90.0      110.0             40.0            39.0
# 2024-01-25 21:50:00         0.0       10.0             60.0            49.0
# 2024-01-13 01:20:00       100.0      120.0             50.0            42.0
# 2024-01-20 03:20:00        90.0      120.0             30.0            35.0
#
# ...

# %%
y_train
# Out:
# date
# 2024-01-02 09:20:00     6.0
# 2024-01-05 09:50:00    10.0
# 2024-01-15 08:50:00     9.0
# 2024-01-13 14:50:00    33.0
# 2024-01-10 11:20:00    49.0
#                        ...
# 2024-01-20 01:20:00    10.0
# 2024-01-16 13:50:00    10.0
# 2024-01-25 21:50:00    10.0
# 2024-01-13 01:20:00    13.0
# 2024-01-20 03:20:00     8.0
# Name: wave_height, Length: 1619, dtype: float64

# %%
y_train = y_train.astype('float')

# %%
rc.fit(X_train, y_train)
# Out:
# RidgeClassifier(alpha=1)

# %%
t = rc.predict(X_test)

# %%
len(t)
# Out:
# 405
